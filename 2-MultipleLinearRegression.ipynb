# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("2-multiplegradesdataset.csv")

# %%
df.head()
# Out:
#    Study Hours  Sleep Hours  Attendance Rate  Social Media Hours  Exam Score
# 0          4.7          7.3             82.9                 3.3        80.7
# 1          3.8          6.6             87.9                 3.3        76.0
# 2          5.0          6.3             88.3                 2.3        89.1
# 3          6.3          7.6             86.0                 3.2        95.9
# 4          3.6          8.0             89.2                 3.3        70.5

# %%
df.describe()
# Out:
#        Study Hours  Sleep Hours  Attendance Rate  Social Media Hours  \
# count     50.00000    50.000000        50.000000            50.00000
# mean       3.66800     7.022000        89.736000             3.09000
# std        1.40123     0.874419         4.924813             0.89699
# min        1.10000     4.400000        80.400000             1.50000
# 25%        2.67500     6.500000        85.625000             2.22500
# 50%        3.60000     7.050000        90.100000             3.20000
# 75%        4.50000     7.575000        92.550000             3.57500
# max        6.80000     8.600000       100.000000             5.70000
#
#        Exam Score
# count    50.00000
# mean     76.07000
# std      11.70915
# min      56.90000
# 25%      68.07500
# 50%      73.55000
# 75%      84.17500
# max     100.00000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Study Hours         50 non-null     float64
#  1   Sleep Hours         50 non-null     float64
#  2   Attendance Rate     50 non-null     float64
#  3   Social Media Hours  50 non-null     float64
#  4   Exam Score          50 non-null     float64
# dtypes: float64(5)
# memory usage: 2.1 KB

# %%
df.isnull().sum()
# Out:
# Study Hours           0
# Sleep Hours           0
# Attendance Rate       0
# Social Media Hours    0
# Exam Score            0
# dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr()
# Out:
#                     Study Hours  Sleep Hours  Attendance Rate  \
# Study Hours            1.000000     0.114015        -0.112860
# Sleep Hours            0.114015     1.000000        -0.222024
# Attendance Rate       -0.112860    -0.222024         1.000000
# Social Media Hours     0.115023    -0.177166         0.068272
# Exam Score             0.804266     0.227694         0.123791
#
#                     Social Media Hours  Exam Score
# Study Hours                   0.115023    0.804266
# Sleep Hours                  -0.177166    0.227694
# Attendance Rate               0.068272    0.123791
# Social Media Hours            1.000000   -0.248743
# Exam Score                   -0.248743    1.000000

# %%
plt.scatter(df['Study Hours'], df['Exam Score'], color='blue')
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.title('Study Hours vs Exam Score')
plt.show()

# %%
sns.regplot(x=df['Study Hours'], y=df['Exam Score'])
# Out:
# <Axes: xlabel='Study Hours', ylabel='Exam Score'>

# %%
df.tail()
# Out:
#     Study Hours  Sleep Hours  Attendance Rate  Social Media Hours  Exam Score
# 45          2.9          5.5             93.9                 3.4        65.9
# 46          3.3          7.3             83.8                 2.1        72.8
# 47          5.6          7.3             83.4                 3.2        81.1
# 48          4.5          7.0             92.6                 3.1        91.0
# 49          1.4          6.8             91.5                 1.9        68.8

# %%
#independent and dependent variables

X = df[["Study Hours", "Sleep Hours", "Attendance Rate", "Social Media Hours" ]]
y= df["Exam Score"]

# %%
X.head()
# Out:
#    Study Hours  Sleep Hours  Attendance Rate  Social Media Hours
# 0          4.7          7.3             82.9                 3.3
# 1          3.8          6.6             87.9                 3.3
# 2          5.0          6.3             88.3                 2.3
# 3          6.3          7.6             86.0                 3.2
# 4          3.6          8.0             89.2                 3.3

# %%
y.head()
# Out:
# 0    80.7
# 1    76.0
# 2    89.1
# 3    95.9
# 4    70.5
# Name: Exam Score, dtype: float64

# %%
#train - test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=15)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 7.64922342e-01,  1.07637448e+00,  2.70413080e-03,
#          6.75932027e-01],
#        [-1.60676425e+00, -3.94765312e-01,  3.42883785e-01,
#          1.46070057e-01],
#        [ 1.39737210e+00,  3.40804586e-01, -1.23795108e+00,
#          1.46070057e-01],
#        [-1.92298913e+00, -1.84602484e-01,  3.82904921e-01,
#         -1.23157107e+00],
#        [ 2.11528804e-01,  2.55603439e-02,  1.48348616e+00,
#         -1.71847126e-01],
#        [ 2.90585024e-01,  8.66211656e-01,  2.08380319e+00,
#          7.81904421e-01],
#        [-2.56398550e-02, -7.10009554e-01, -1.51809903e+00,
#          1.46070057e-01],
#        [ 9.23034781e-01, -7.10009554e-01, -2.57433252e-01,
#         -8.07681490e-01],
#        [-4.20920953e-01,  3.40804586e-01, -1.15790881e+00,
#         -1.01962628e+00],
#        [-2.56398550e-02, -3.94765312e-01, -3.37475524e-01,
#          2.52042451e-01],
#        [ 3.69641243e-01,  5.50967414e-01, -1.15790881e+00,
#         -1.65546064e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test[0]
# Out:
# array([-1.29053937, -0.49984673,  1.62356013,  0.67593203])

# %%
df.iloc[0]
# Out:
# Study Hours            4.7
# Sleep Hours            7.3
# Attendance Rate       82.9
# Social Media Hours     3.3
# Exam Score            80.7
# Name: 0, dtype: float64

# %%
new_student = [[5, 7, 90, 4]]

# %%
new_student_scaled = scaler.transform(new_student)
# Out:
# c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
regression.predict(new_student_scaled)
# Out:
# array([82.23465969])

# %% [markdown]
# # Bu hucre, temel ML akisindaki her satirin ne yaptigini aciklar.
# # Temel iskelet: veriden modele (predict'e kadar)
#
# # CSV okumak ve tabloyla calismak icin pandas
#  # import pandas as pd
#
# # Veriyi egitim/teste ayirmak icin train_test_split
#  # from sklearn.model_selection import train_test_split
#
# # Sayisal ozellikleri standartlastirmak icin StandardScaler
#  # from sklearn.preprocessing import StandardScaler
#
# # Lineer regresyon modelini kullanmak icin LinearRegression
#  # from sklearn.linear_model import LinearRegression
#
# # CSV dosyasini okuyup DataFrame olusturur
#  # df = pd.read_csv("2-multiplegradesdataset.csv")
#
# # Girdi ozelliklerini (bagimsiz degiskenleri) secer
#  # X = df[["Study Hours", "Sleep Hours", "Attendance Rate", "Social Media Hours"]]
#
# # Hedef degiskeni (tahmin edilecek degeri) secer
#  # y = df["Exam Score"]
#
# # Veriyi egitim ve test olarak ayirir
#  # X_train, X_test, y_train, y_test = train_test_split(
# #     X, y, test_size=0.25, random_state=15
# # )
#
# # Standartlastirici nesnesini olusturur
#  # scaler = StandardScaler()
#
# # Egitim verisinde ortalama/std ogrenir ve uygular
#  # X_train = scaler.fit_transform(X_train) --> fit_transform, hem fit (ogrenme) hem de transform (donusturme) islemini tek adimda yapar
#
# # Ayni olcek ile test verisini donusturur
#  # X_test = scaler.transform(X_test)
#
# # Lineer regresyon modeli nesnesini olusturur
#  # regression = LinearRegression()
#
# # Modeli egitim verisiyle egitir
#  # regression.fit(X_train, y_train)

# %%
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([ 67.04704385,  57.90545589,  83.63084813,  63.69399367,
#         69.73079557,  80.76485587,  93.76445033,  65.93953528,
#         64.58675718,  78.42296106,  56.67860558,  64.44046585,
#        102.60438643])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print("mse:", mse)
print("mae:", mae)
# Out:
# mse: 14.600589378986278
# mae: 3.2770264859627876

# %%
score = r2_score(y_test, y_pred)
print("R2 Score:", score)
# Out:
# R2 Score: 0.9156707345772709

# %%
plt.scatter(y_test, y_pred, color='blue')
plt.xlabel('Actual Exam Scores')
plt.ylabel('Predicted Exam Scores')
plt.show()

# %%
y_pred
# Out:
# array([ 67.04704385,  57.90545589,  83.63084813,  63.69399367,
#         69.73079557,  80.76485587,  93.76445033,  65.93953528,
#         64.58675718,  78.42296106,  56.67860558,  64.44046585,
#        102.60438643])

# %%
residuals = y_test - y_pred

# %%
print(residuals)
# Out:
# 35    2.652956
# 37    3.894544
# 41   -1.930848
# 26    2.006006
# 38   -3.130796
# 43    3.335144
# 3     2.135550
# 33   -3.039535
# 30   -2.686757
# 36   -9.822961
# 14    2.321394
# 16   -3.040466
# 20   -2.604386
# Name: Exam Score, dtype: float64

# %%
sns.displot(residuals, kind='kde')

# %%
regression.intercept_
# Out:
# np.float64(77.41081081081082)

# %%
regression.coef_
# Out:
# array([ 9.28014703,  1.78967062,  3.24340001, -4.08127695])

# %%
new_student = [[5,7,90,4]]

# %%
students = [
    [5,7,90,4],
    [3,6,85,4],
    [4,7,80,3]
]

# %%
regression.predict(scaler.transform(students))
# Out:
# c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([82.23465969, 62.43586785, 72.73292556])

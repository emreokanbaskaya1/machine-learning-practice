# %%
#https://github.com/shankarpandala/lazypredict

# %%
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.3.0-py3-none-any.whl.metadata (24 kB)
# Collecting click (from lazypredict)
#   Downloading click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: scikit-learn>=1.0 in C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from lazypredict) (1.8.0)
# Requirement already satisfied: pandas>=1.3 in C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from lazypredict) (3.0.3)
# Collecting tqdm>=4.0 (from lazypredict)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: joblib>=1.0 in C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: numpy>=1.21 in C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from lazypredict) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\user\AppData\Roaming\Python\Python314\site-packages (from pandas>=1.3->lazypredict) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.3->lazypredict) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\user\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->lazypredict) (1.17.0)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn>=1.0->lazypredict) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn>=1.0->lazypredict) (3.6.0)
# Requirement already satisfied: colorama in C:\Users\user\AppData\Roaming\Python\Python314\site-packages (from tqdm>=4.0->lazypredict) (0.4.6)
# Downloading lazypredict-0.3.0-py3-none-any.whl (71 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
# Installing collected packages: tqdm, click, lazypredict
#
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [click]
#    -------------------------- ------------- 2/3 [lazypredict]
#    ---------------------------------------- 3/3 [lazypredict]
#
# Successfully installed click-8.4.1 lazypredict-0.3.0 tqdm-4.67.3
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
#   WARNING: The script tqdm.exe is installed in 'C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script lazypredict.exe is installed in 'C:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
diabetes = datasets.load_diabetes()

# %%
type(diabetes)
# Out:
# sklearn.utils._bunch.Bunch

# %%
diabetes.DESCR
# Out:
# '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n:Number of Instances: 442\n\n:Number of Attributes: First 10 columns are numeric predictive values\n\n:Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n:Attribute Information:\n    - age     age in years\n    - sex\n    - bmi     body mass index\n    - bp      average blood pressure\n    - s1      tc, total serum cholesterol\n    - s2      ldl, low-density lipoproteins\n    - s3      hdl, high-density lipoproteins\n    - s4      tch, total cholesterol / HDL\n    - s5      ltg, possibly log of serum triglycerides level\n    - s6      glu, blood sugar level\n\nNote: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).\n\nSource URL:\nhttps://www4.stat.ncsu.edu/~boos/var.select/diabetes.html\n\nFor more information see:\nBradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.\n(https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)\n'

# %%
diabetes.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10))

# %%
diabetes.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
X, y = shuffle(diabetes.data, diabetes.target, random_state=13)

# %%
X = X.astype(np.float32)

# %%
offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# %%
X.shape
# Out:
# (442, 10)

# %%
X[0]
# Out:
# array([-0.00551456, -0.04464164,  0.05630714, -0.03665608, -0.04835136,
#        -0.04296262, -0.07285395,  0.03799897,  0.05078203,  0.0569118 ],
#       dtype=float32)

# %%
y[0]
# Out:
# np.float64(272.0)

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\deprecation.py:71: FutureWarning: Class PassiveAggressiveRegressor is deprecated; this is deprecated in version 1.8 and will be removed in 1.10. Use `SGDRegressor(loss='epsilon_insensitive', penalty=None, learning_rate='pa1', eta0 = 1.0)` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(models)
# Out:
#                                Adjusted R-Squared  R-Squared        RMSE  \
# Model
# ExtraTreesRegressor                      0.378921   0.520076   54.220181
# OrthogonalMatchingPursuitCV              0.374947   0.517004   54.393399
# Lasso                                    0.373483   0.515873   54.457049
# LassoLars                                0.373474   0.515866   54.457460
# LarsCV                                   0.371500   0.514341   54.543154
# LassoCV                                  0.370413   0.513501   54.590300
# PassiveAggressiveRegressor               0.366958   0.510831   54.739889
# LassoLarsIC                              0.364985   0.509306   54.825149
# SGDRegressor                             0.364307   0.508783   54.854375
# RidgeCV                                  0.363002   0.507774   54.910674
# Ridge                                    0.363002   0.507774   54.910679
# BayesianRidge                            0.362297   0.507229   54.941063
# LinearRegression                         0.361749   0.506806   54.964648
# TransformedTargetRegressor               0.361749   0.506806   54.964648
# LassoLarsCV                              0.361749   0.506806   54.964654
# Lars                                     0.358827   0.504548   55.090312
# ElasticNetCV                             0.356159   0.502486   55.204825
# HuberRegressor                           0.355251   0.501785   55.243742
# RandomForestRegressor                    0.347778   0.496010   55.562969
# AdaBoostRegressor                        0.340416   0.490322   55.875662
# HistGradientBoostingRegressor            0.335632   0.486625   56.077921
# PoissonRegressor                         0.323033   0.476889   56.607187
# ElasticNet                               0.301755   0.460447   57.489920
# KNeighborsRegressor                      0.299855   0.458979   57.568054
# OrthogonalMatchingPursuit                0.292421   0.453235   57.872882
# BaggingRegressor                         0.277859   0.441982   58.465384
# GradientBoostingRegressor                0.247009   0.418143   59.701142
# TweedieRegressor                         0.244215   0.415984   59.811792
# GammaRegressor                           0.223895   0.400283   60.610504
# RANSACRegressor                          0.203535   0.384550   61.400378
# LinearSVR                                0.116707   0.317455   64.660657
# ExtraTreeRegressor                       0.002019   0.228833   68.730391
# NuSVR                                   -0.066704   0.175728   71.057466
# SVR                                     -0.096413   0.152772   72.040169
# DummyRegressor                          -0.297553  -0.002655   78.370078
# QuantileRegressor                       -0.346561  -0.040525   79.836360
# DecisionTreeRegressor                   -0.469826  -0.135775   83.410498
# GaussianProcessRegressor                -0.769174  -0.367089   91.510930
# MLPRegressor                            -1.867720  -1.215965  116.508077
# KernelRidge                             -5.038214  -3.665893  169.060415
#
#                                Time Taken
# Model
# ExtraTreesRegressor              0.186563
# OrthogonalMatchingPursuitCV      0.011500
# Lasso                            0.008524
# LassoLars                        0.008742
# LarsCV                           0.015282
# LassoCV                          0.060467
# PassiveAggressiveRegressor       0.020065
# LassoLarsIC                      0.009760
# SGDRegressor                     0.007263
# RidgeCV                          0.010067
# Ridge                            0.010761
# BayesianRidge                    0.012991
# LinearRegression                 0.007477
# TransformedTargetRegressor       0.007175
# LassoLarsCV                      0.019104
# Lars                             0.009395
# ElasticNetCV                     0.048158
# HuberRegressor                   0.016812
# RandomForestRegressor            0.297364
# AdaBoostRegressor                0.068118
# HistGradientBoostingRegressor    0.162335
# PoissonRegressor                 0.013651
# ElasticNet                       0.006589
# KNeighborsRegressor              0.011144
# OrthogonalMatchingPursuit        0.007539
# BaggingRegressor                 0.059372
# GradientBoostingRegressor        0.093517
# TweedieRegressor                 0.009123
# GammaRegressor                   1.781869
# RANSACRegressor                  0.074544
# LinearSVR                        0.008201
# ExtraTreeRegressor               0.007182
# NuSVR                            0.013544
# SVR                              0.012873
# DummyRegressor                   0.006429
# QuantileRegressor                0.032746
# DecisionTreeRegressor            0.013545
# GaussianProcessRegressor         0.020726
# MLPRegressor                     0.231486
# KernelRidge                      0.015621
